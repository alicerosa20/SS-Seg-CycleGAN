# %%
from skimage import io
from patchify import patchify, unpatchify
import numpy as np
from matplotlib import pyplot as plt
from tifffile import imread, imsave, imwrite
import math
from PIL import Image
import os, shutil
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate
from skimage import io
import numpy as np
from matplotlib import pyplot as plt
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tifffile import imread
import math
import xlwt
from xlwt import Workbook
from torch.nn import ReflectionPad3d
import torch
from matplotlib.pyplot import imshow
from keras.callbacks import ModelCheckpoint
from focal_loss import BinaryFocalLoss
import torch
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()
from keras.layers.merge import Concatenate

# %%
img = imread('./Dataset_3/Images/Crop2.tif')[256:256*2,256:256*2,:,:]
imshow(img[:,:,25,:])

mask = imread('./Dataset_3/Masks/Crop2.tif')[256:256*2,256:256*2,:,:]
plt.figure()
imshow(mask[:,:,25,:])

imwrite( './Dataset/img_patch_10.tif', img, photometric='rgb')
imwrite( './Dataset/mask_img_patch_10.tif', mask, photometric='rgb')

# %% [markdown]
# # Prepare Train, Validation and Test Set

# %%
def patchify_rgb(image, patch_size=(64,64,32), step=32):
    
    img_patches_R = patchify(image[:,:,:,0], patch_size, step=step)
    input_img_R = np.reshape(img_patches_R, (-1, img_patches_R.shape[3], img_patches_R.shape[4], img_patches_R.shape[5]))

    img_patches_G = patchify(image[:,:,:,1], patch_size, step=step) 
    input_img_G = np.reshape(img_patches_G, (-1, img_patches_G.shape[3], img_patches_G.shape[4], img_patches_G.shape[5]))

    if image.shape[3] == 3:
      img_patches_B = patchify(image[:,:,:,2], patch_size, step=step)
      input_img_B = np.reshape(img_patches_B, (-1, img_patches_B.shape[3], img_patches_B.shape[4], img_patches_B.shape[5]))
      img_patches_rgb = np.stack((input_img_R,input_img_G,input_img_B), axis=-1)
    else:
      img_patches_rgb = np.stack((input_img_R,input_img_G), axis=-1)
    
    return img_patches_rgb

# %%
def rgb_to_label(mask):
      
    label_mask = np.stack((mask[:,:,:,0],mask[:,:,:,1]), axis=-1)
    
    return label_mask

# %%
def padding(image,size):

    img_reshape = np.moveaxis(image, -1, 0)
    
    m = ReflectionPad3d((0,size[2]-image.shape[2],0,size[1]-image.shape[1],0,size[0]-image.shape[0]))
    input = torch.tensor(img_reshape, dtype=torch.float)
    output = m(input)
    pad_img = output.numpy()
    pad_img = np.moveaxis(pad_img, 0, -1)
    
    return pad_img

# %%
def dir_setup(patches_dir):
  
  
  train_dir = os.path.join(patches_dir, 'Train')
  if os.path.exists(train_dir)==False:
        os.mkdir(train_dir)

  train_dir_img = os.path.join(train_dir, 'Images')
  if os.path.exists(train_dir_img)==False:
        os.mkdir(train_dir_img)

  train_dir_mask = os.path.join(train_dir, 'Masks')
  if os.path.exists(train_dir_mask)==False:
        os.mkdir(train_dir_mask)

  val_dir = os.path.join(patches_dir, 'Validation')
  if os.path.exists(val_dir)==False:
        os.mkdir(val_dir)

  val_dir_img = os.path.join(val_dir, 'Images')
  if os.path.exists(val_dir_img)==False:
        os.mkdir(val_dir_img)

  val_dir_mask = os.path.join(val_dir, 'Masks')
  if os.path.exists(val_dir_mask)==False:
        os.mkdir(val_dir_mask)

  tst_dir = os.path.join(patches_dir, 'Test')
  if os.path.exists(tst_dir)==False:
        os.mkdir(tst_dir)

  tst_dir_img = os.path.join(tst_dir, 'Images')
  if os.path.exists(tst_dir_img)==False:
        os.mkdir(tst_dir_img)

  tst_dir_mask = os.path.join(tst_dir, 'Masks')
  if os.path.exists(tst_dir_mask)==False:
        os.mkdir(tst_dir_mask)

  return [train_dir_img, train_dir_mask, val_dir_img, val_dir_mask, tst_dir_img, tst_dir_mask]

# %%
def train_validation_test_setup(img_dir, mask_dir, patches_dir):

  img_name = os.listdir(img_dir)

  #train, validate, test = np.split(img_name, [int(len(img_name)*0.6), int(len(img_name)*0.8)])
  train = ["Crop1.tif", "Crop2.tif", "Crop3.tif", "Crop8_BC.tif"]
  validate = ["Crop4.tif", "Crop6_BC.tif"]
  test = ["Crop5_BC.tif", "Crop7_BC.tif"]

  n_train = len(train)
  n_validation = len(validate)
  n_test = len(test)

  [train_dir_img, train_dir_mask, val_dir_img, val_dir_mask, tst_dir_img, tst_dir_mask] = dir_setup(patches_dir)

  for i in range(n_train):
    image = imread(img_dir + train[i])
    mask = imread(mask_dir + train[i])

    image = padding(image, (image.shape[0], image.shape[1], 64, image.shape[3]))
    mask = padding(mask, (mask.shape[0], mask.shape[1], 64, mask.shape[3]))

    # normalize data
    nor_image = image / 255.
    nor_mask = mask / 255.

    # labeling data
    label_mask = rgb_to_label(nor_mask)

    img_patches = patchify_rgb(nor_image,(64,64,64),64)
    mask_patches = patchify_rgb(label_mask,(64,64,64),64)

    for p in range(img_patches.shape[0]):
      imwrite(train_dir_img + '/img_patch_' + str(i+1) + str(p) + '.tif', img_patches[p,:,:,:])

    for k in range(mask_patches.shape[0]):
      imwrite(train_dir_mask + '/img_patch_' + str(i+1) + str(k) + '.tif', mask_patches[k,:,:,:])


  for j in range(n_validation):
    image = imread(img_dir + validate[j])
    mask = imread(mask_dir + validate[j])

    image = padding(image, (image.shape[0], image.shape[1], 64, image.shape[3]))
    mask = padding(mask, (mask.shape[0], mask.shape[1], 64, mask.shape[3]))

    # normalize data
    nor_image = image / 255.
    nor_mask = mask / 255.

    # labeling data
    label_mask = rgb_to_label(nor_mask)

    img_patches = patchify_rgb(nor_image,(64,64,64),64)
    mask_patches = patchify_rgb(label_mask,(64,64,64),64)

    for p in range(img_patches.shape[0]):
      imwrite(val_dir_img + '/img_patch_' + str(j+1) + str(p) + '.tif', img_patches[p,:,:,:])

    for k in range(mask_patches.shape[0]):
      imwrite(val_dir_mask + '/img_patch_' + str(j+1) + str(k) + '.tif', mask_patches[k,:,:,:])


  for fname in test:
    src_img = os.path.join(img_dir, fname)
    dst_img = os.path.join(tst_dir_img, fname)
    shutil.copyfile(src_img, dst_img)

    src_mask = os.path.join(mask_dir, fname)
    dst_mask = os.path.join(tst_dir_mask, fname)
    shutil.copyfile(src_mask, dst_mask)

# %%
img_dir = './Dataset/Images_Pre/'
mask_dir = './Dataset/Masks/'
patches_dir = './Dataset/Patches_Pre_64/'
train_validation_test_setup(img_dir, mask_dir, patches_dir)

# %%
a = imread('./Dataset/Patches_Pre_64/Train/Images/img_patch_112.tif')
plt.figure(1)
imshow(a[:,:,20,:])
b = imread('./Dataset/Patches_Pre_64/Train/Masks/img_patch_112.tif')
_b = np.zeros((64,64,64,3))
_b[:,:,:,:2] = b
plt.figure(2)
imshow(_b[:,:,20,:])
print(_b.shape)

#a = a*255.0
#a = a.astype('uint8')

#imwrite('./Dataset/' + 'img_patch.tif' , a, photometric='rgb')

#_b = _b*255.0
#_b = _b.astype('uint8')

#imwrite('./Dataset/' + 'mask_patch.tif' , _b, photometric='rgb')
# Out:
# (64, 64, 64, 3)

# %% [markdown]
# # Train Model

# %%
import sys  
sys.path.insert(0, './')

# %%
import data_generator
from data_generator import DataGenerator

# %%
def conv_block(inputs, num_filters):
    x = Conv3D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)    
    x = Activation("relu")(x)

    x = Conv3D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

#Encoder block: Conv block followed by maxpooling

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPooling3D((2, 2, 2))(x)
    return x, p   

#Decoder block
#skip features gets input from encoder for concatenation

def decoder_block(inputs, skip_features, num_filters):
    x = Conv3DTranspose(num_filters, (2, 2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %%
#Build Unet using the blocks
def build_unet(input_shape, n_classes, n_filters_start=32, growth_factor=2):
    inputs = Input(input_shape)
    n_filters = n_filters_start
    
    s1, p1 = encoder_block(inputs, n_filters)
    n_filters *= growth_factor
    
    s2, p2 = encoder_block(p1, n_filters)
    n_filters *= growth_factor
    
    s3, p3 = encoder_block(p2, n_filters)
    n_filters *= growth_factor
    
    s4, p4 = encoder_block(p3, n_filters)
    n_filters *= growth_factor

    b1 = conv_block(p4, n_filters) #Bridge
    
    n_filters //= growth_factor
    d1 = decoder_block(b1, s4, n_filters)
    
    n_filters //= growth_factor
    d2 = decoder_block(d1, s3, n_filters)
    
    n_filters //= growth_factor
    d3 = decoder_block(d2, s2, n_filters)
    
    n_filters //= growth_factor
    d4 = decoder_block(d3, s1, n_filters)

    outputs = Conv3D(n_classes, 1, padding="same", activation='sigmoid')(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
# Loss Function and coefficients to be used during training:
def dice_coefficient(y_true, y_pred):
    smoothing_factor = 1
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    return (2. * K.sum(flat_y_true * flat_y_pred) + smoothing_factor) / (K.sum(flat_y_true) + K.sum(flat_y_pred) + smoothing_factor)
    
def dice_coefficient_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

# %%
def model_plots(history, plot_dir):
  #plot the training and validation IoU and loss at each epoch
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(1, len(loss) + 1)

  plt.figure(1)
  plt.plot(epochs, loss, 'y', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.savefig(plot_dir + '/loss_plot_aft_pre.png')

  acc = history.history['dice_coefficient']
  val_acc = history.history['val_dice_coefficient']

  plt.figure(2)
  plt.plot(epochs, acc, 'y', label='Training Dice')
  plt.plot(epochs, val_acc, 'r', label='Validation Dice')
  plt.title('Training and validation Dice')
  plt.xlabel('Epochs')
  plt.ylabel('Dice')
  plt.legend()
  plt.savefig(plot_dir + '/dice_plot_aft_pre.png')

# %%
batch_size = 4

traingen = DataGenerator('Train', batch_size=batch_size, img_size=(64,64,64,2), mask_size=(64,64,64,2))

valgen = DataGenerator('Validation', batch_size=batch_size, img_size=(64,64,64,2), mask_size=(64,64,64,2))

#Define parameters for our model.

patch_size = (64,64,64,2)

LR = 0.0001
optim = Adam(LR,amsgrad=True)

model = build_unet(patch_size, n_classes=2)

model.summary()

#for layer in model.layers:
#    print(layer.output_shape)

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

#model.compile(optimizer = optim, loss=dice_coefficient_loss, metrics=dice_coefficient)

#checkpoint = ModelCheckpoint('./Models_UNET')

#Fit the model
#history = model.fit(traingen,
#         validation_data=valgen,
#         epochs=100, verbose=1, callbacks=[early_stopping, checkpoint])
# Out:
# 2022-10-21 13:51:06.543641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.555385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.555653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.556704: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-21 13:51:06.557176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.557431: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.557653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.936017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.936181: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.936307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-21 13:51:06.936410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7100 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 64,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 64, 64, 64, 3 1760        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64, 3 128         conv3d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64, 3 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 64, 64, 64, 3 27680       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64, 3 128         conv3d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 64, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 32, 32, 32, 3 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 32, 32, 32, 6 55360       max_pooling3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32, 6 256         conv3d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 32, 32, 32, 6 110656      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 32, 6 256         conv3d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 32, 6 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 16, 16, 16, 6 0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 16, 16, 16, 1 221312      max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 16, 1 512         conv3d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 16, 1 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 16, 16, 16, 1 442496      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 16, 1 512         conv3d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 16, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 8, 8, 8, 128) 0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 8, 8, 8, 256) 884992      max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 8, 256) 1024        conv3d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 8, 256) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 8, 8, 8, 256) 1769728     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 8, 256) 1024        conv3d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 8, 256) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 4, 4, 4, 256) 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 4, 4, 4, 512) 3539456     max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 4, 512) 2048        conv3d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 4, 512) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 4, 4, 4, 512) 7078400     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 4, 512) 2048        conv3d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 4, 512) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 8, 8, 8, 256) 1048832     activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 8, 512) 0           conv3d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 8, 8, 8, 256) 3539200     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 8, 256) 1024        conv3d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 8, 256) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 8, 8, 8, 256) 1769728     activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 8, 256) 1024        conv3d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 8, 256) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 16, 16, 16, 1 262272      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 16, 2 0           conv3d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 16, 16, 16, 1 884864      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 16, 1 512         conv3d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 16, 1 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 16, 16, 16, 1 442496      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 16, 1 512         conv3d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 16, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 32, 32, 32, 6 65600       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 32, 1 0           conv3d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 32, 32, 32, 6 221248      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 32, 6 256         conv3d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 32, 6 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 32, 32, 32, 6 110656      activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 32, 6 256         conv3d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 32, 6 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 64, 64, 64, 3 16416       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64, 6 0           conv3d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 64, 64, 64, 3 55328       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64, 3 128         conv3d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 64, 3 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 64, 64, 64, 3 27680       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 64, 3 128         conv3d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 64, 3 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 64, 64, 64, 2 66          activation_17[0][0]
# ==================================================================================================
# Total params: 22,588,002
# Trainable params: 22,582,114
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
plot_dir = './Dataset/Model_Plots'
#os.mkdir(plot_dir)

model_plots(history, plot_dir)

model.save('./Models_UNET/UNET_3D_Final_aft_pre.h5')

# %% [markdown]
# # Test Model

# %%
def padding(image,size):

    img_reshape = np.moveaxis(image, -1, 0)
    
    m = ReflectionPad3d((0,size[2]-image.shape[2],0,size[1]-image.shape[1],0,size[0]-image.shape[0]))
    input = torch.tensor(img_reshape, dtype=torch.float)
    output = m(input)
    pad_img = output.numpy()
    pad_img = np.moveaxis(pad_img, 0, -1)
    
    return pad_img

# %%
def thresholding(patch_prediction):
  patch_ind_nuclei = np.argwhere(patch_prediction[:,:,:,0] > 0.5)
  patch_ind_golgi = np.argwhere(patch_prediction[:,:,:,1] > 0.5)

  patch_prediction_thr = np.zeros((patch_prediction.shape[0],patch_prediction.shape[1],patch_prediction.shape[2],3))

  for i in range(patch_ind_nuclei.shape[0]):
    patch_prediction_thr[patch_ind_nuclei[i,0],patch_ind_nuclei[i,1],patch_ind_nuclei[i,2],0]=1 

  for j in range(patch_ind_golgi.shape[0]):
    patch_prediction_thr[patch_ind_golgi[j,0],patch_ind_golgi[j,1],patch_ind_golgi[j,2],1]=1

  return patch_prediction_thr

# %%
def pred_mask(image, mask_shape):
  patch_size = 64
  step = 48

  pred_mask = np.zeros(((image.shape[0] // step)*step + patch_size,(image.shape[1] // step)*step + patch_size,64,3))
  _image = padding(image, ((image.shape[0] // step)*step + patch_size,(image.shape[1] // step)*step + patch_size,64,3))

  i = 0
  while i + patch_size <= _image.shape[0]:
    j = 0
    while j + patch_size <= _image.shape[1]:

        tst_patch = _image[i:i+patch_size, j:j+patch_size, :, :]
        tst_patch = np.array([tst_patch / 255.])
        preds_tst = my_model.predict(tst_patch)
        pred_patch = preds_tst[0,:,:,:,:]
        pred_patch_thr = thresholding(pred_patch)

        pred_mask[i:i+patch_size, j:j+patch_size,:,0] = np.array(np.logical_or(pred_mask[i:i+patch_size, j:j+patch_size, :,0], pred_patch_thr[:,:,:,0], dtype = 'float64'))
        pred_mask[i:i+patch_size, j:j+patch_size,:,1] = np.array(np.logical_or(pred_mask[i:i+patch_size, j:j+patch_size, :,1], pred_patch_thr[:,:,:,1], dtype = 'float64'))
        pred_mask[i:i+patch_size, j:j+patch_size,:,2] = 0

        j += step
        
    i += step
    
  _pred_mask = np.zeros(mask_shape)
  _pred_mask = pred_mask[0:mask_shape[0],0:mask_shape[1],0:mask_shape[2],:]

  return _pred_mask, _image

# %%
def dice_coefficient(y_true, y_pred):
    smoothing_factor = 1
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    return (2. * K.sum(flat_y_true * flat_y_pred) + smoothing_factor) / (K.sum(flat_y_true) + K.sum(flat_y_pred) + smoothing_factor)

def precision(y_true, y_pred):
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    return(K.sum(flat_y_true * flat_y_pred) / K.sum(flat_y_pred) )

def recall(y_true, y_pred):
    flat_y_true = K.flatten(y_true)
    flat_y_pred = K.flatten(y_pred)
    return(K.sum(flat_y_true * flat_y_pred) / K.sum(flat_y_true) )

# %%
def metrics(mask, _pred_mask):
  _mask = mask/255.

  dice_coef_nuclei = dice_coefficient(_mask[:,:,:,1],_pred_mask[:,:,:,1])
  dice_coef_golgi = dice_coefficient(_mask[:,:,:,0],_pred_mask[:,:,:,0])
  prec_nuclei = precision(_mask[:,:,:,1],_pred_mask[:,:,:,1])
  prec_golgi = precision(_mask[:,:,:,0],_pred_mask[:,:,:,0])
  recall_nuclei = recall(_mask[:,:,:,1],_pred_mask[:,:,:,1])
  recall_golgi = recall(_mask[:,:,:,0],_pred_mask[:,:,:,0])

  return [round(dice_coef_nuclei.numpy(),4), round(dice_coef_golgi.numpy(),4), 
          round(prec_nuclei.numpy(),4), round(prec_golgi.numpy(),4), round(recall_nuclei.numpy(),4),
          round(recall_golgi.numpy(),4)]

# %%
def write_to_excel(wb,sheet_name,metrics, result_dir):

  # add_sheet is used to create sheet.
  sheet1 = wb.add_sheet(sheet_name)

  sheet1.write(0, 0, 'Dice Coeffient Nuclei')
  sheet1.write(0, 1, 'Dice Coeffient Golgi')
  sheet1.write(0, 2, 'Precision Nuclei')
  sheet1.write(0, 3, 'Precision Golgi')
  sheet1.write(0, 4, 'Recall Nuclei')
  sheet1.write(0, 5, 'Recall Golgi')
  sheet1.write(1, 0, metrics[0])
  sheet1.write(1, 1, metrics[1])
  sheet1.write(1, 2, metrics[2])
  sheet1.write(1, 3, metrics[3])
  sheet1.write(1, 4, metrics[4])
  sheet1.write(1, 5, metrics[5])

  wb.save(result_dir + '/results_metrics_aft_pre.xlsx')

# %%
def test_model(base_dir):

  fnames = os.listdir(base_dir + 'Images/')

  # Workbook is created
  wb = Workbook()

  result_dir = './Dataset/Results_UNET'
  if os.path.exists(result_dir)==False:
        os.mkdir(result_dir)

  for i in range(len(fnames)):

    image = (imread(base_dir + 'Images/' + fnames[i]))[:,:,:,:2]
    mask = imread(base_dir + 'Masks/' + fnames[i])

    predicted_mask, img_tst = pred_mask(image, image.shape)

    _predicted_mask = predicted_mask*255.0
    _predicted_mask = _predicted_mask.astype('uint8')

    imwrite(result_dir + '/pre_pred_mask_' + fnames[i] , _predicted_mask, photometric='rgb')

    _metrics = metrics(mask, predicted_mask)

    write_to_excel(wb,'Sheet_' + fnames[i].split('.')[0], _metrics, result_dir)
    
  return img_tst

# %%
#Load the pretrained model for testing and predictions.
import time
start_time = time.time()

from keras.models import load_model
my_model = load_model('./Models_UNET/UNET_3D_Final_aft_pre.h5', compile=False)
#If you load a different model do not forget to preprocess accordingly. 

base_dir = './Dataset/Patches_Pre_64/Test/'

img_tst = test_model(base_dir)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2022-10-17 18:16:02.680593: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:02.685491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:02.685650: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:02.686242: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-17 18:16:02.686543: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:02.686681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:02.686811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:03.056381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:03.056550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:03.056686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-17 18:16:03.056786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7102 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-10-17 18:16:04.068037: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-10-17 18:16:04.613366: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101
# 2022-10-17 18:16:04.766656: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-17 18:16:04.766967: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-17 18:16:04.766988: W tensorflow/stream_executor/gpu/asm_compiler.cc:77] Couldn't get ptxas version string: Internal: Couldn't invoke ptxas --version
# 2022-10-17 18:16:04.767387: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-17 18:16:04.767438: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# --- 34.50459098815918 seconds ---
